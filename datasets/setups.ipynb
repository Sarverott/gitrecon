# %%
import huggingface_hub

#from huggingface_hub import login, upload_folder, hf_hub_download


# snapshot_download(repo_id="google/fleurs", repo_type="dataset")


# huggingface_hub.snapshot_download(repo_id="Apokryf/minimap-of-uce", repo_type="dataset", local_dir="./imperialmap")

# #huggingface_hub.upload_folder(folder_path="./minimap-of-uce", repo_id="Apokryf/minimap-of-uce", repo_type="dataset")



# map_of_empire = load_dataset("Apokryf/minimap-of-uce", data_dir="./imperialmap")

# map_of_empire.push_to_hub("Apokryf/minimap-of-uce")

# %%
huggingface_hub.login()

# %%
huggingface_hub.snapshot_download(
    repo_id="Apokryf/minimap-of-uce", 
    repo_type="dataset", 
    local_dir="./imperialmap"
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# '/home/sarverott/__WORKSHOP/forge/inceptorium-apokryf/gistrecon/datasets/imperialmap'

# %%
huggingface_hub.upload_folder(
    folder_path="./imperialmap", 
    repo_id="Apokryf/minimap-of-uce", 
    repo_type="dataset"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/datasets/Apokryf/minimap-of-uce/commit/66efb3041990103fb651c4201649c20dcf57f703', commit_message='Upload folder using huggingface_hub', commit_description='', oid='66efb3041990103fb651c4201649c20dcf57f703', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Apokryf/minimap-of-uce', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Apokryf/minimap-of-uce'), pr_revision=None, pr_num=None)

# %%
import os

os.mkdir("./imperialmap/store-areas")

#os.listdir("./imperialmap/federations")
