# %%
from huggingface_hub import login, upload_folder, load_dataset


login()


# upload_folder(folder_path="./minimap-of-uce", repo_id="Apokryf/minimap-of-uce", repo_type="dataset")

map_of_empire = load_dataset("Apokryf/minimap-of-uce", data_dir="./imperialmap")

map_of_empire.push_to_hub("Apokryf/minimap-of-uce")
