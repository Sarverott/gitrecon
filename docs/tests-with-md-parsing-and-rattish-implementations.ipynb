# %%
import bs4 # pip install beautifulsoup4
import requests # pip install requests
import marko # pip install marko
import IPython # pip install IPython
import urllib # standard lib of python3
import json # standard lib of python3
import yaml # pip install PyYAML
import lark

[requests, marko, IPython, urllib, bs4, yaml, json, lark]

# %%
# as example the llm info briefing about task tool
md_url = "https://taskfile.dev/llms.txt"
md_url
# Out:
# 'https://taskfile.dev/llms.txt'

# %%
# rest get requesting
md_text = requests.get(md_url).text
md_text
# Out:
# "# Task\n\n> The Modern Task Runner\n\nA fast, cross-platform build tool inspired by Make, designed for modern workflows.\n\n## Table of Contents\n\n\n\n\n\n### Reference\n\n- [Taskfile Schema Reference](/docs/reference/schema.md): A reference for the Taskfile schema\n- [Environment Reference](/docs/reference/environment.md): A reference for the Taskfile environment variables\n- [Configuration Reference](/docs/reference/config.md): Complete reference for the Task config files and env vars\n- [Command Line Interface Reference](/docs/reference/cli.md): Complete reference for Task CLI commands, flags, and exit codes\n- [Templating Reference](/docs/reference/templating.md): Comprehensive guide to Task's templating system with Go text/template, special variables, and available functions\n- [Package API Reference](/docs/reference/package.md): A reference for Task's Golang package API\n\n### Experiments\n\n- [Env Precedence (#1038)](/docs/experiments/env-precedence.md): Experiment to change the precedence of environment variables in Task\n- [Gentle Force (#1200)](/docs/experiments/gentle-force.md): Experiment to modify the behavior of the --force flag in Task\n- [Remote Taskfiles (#1317)](/docs/experiments/remote-taskfiles.md): Experimentation for using Taskfiles stored in remote locations\n\n### Deprecations\n\n- [Completion Scripts](/docs/deprecations/completion-scripts.md): Deprecation of direct completion scripts in Task’s Git directory\n- [Template Functions](/docs/deprecations/template-functions.md): Deprecation of some templating functions in Task, with guidance on their replacements.\n- [Version 2 Schema (#1197)](/docs/deprecations/version-2-schema.md): Deprecation of Taskfile schema version 2 and migration to version 3\n\n### Other\n\n- [--- Template ---](/docs/deprecations/template.md): Template for documenting deprecated features in Task\n- [--- Template ---](/docs/experiments/template.md)\n- [Community](/docs/community.md): Task community contributions, installation methods, and integrations maintained by third parties\n- [FAQ](/docs/faq.md): Frequently asked questions about Task, including ETAs, shell limitations, and Windows compatibility\n- [Getting Started](/docs/getting-started.md): Guide for getting started with Task\n- [Guide](/docs/guide.md)\n- [Installation](/docs/installation.md): Installation methods for Task\n- [Integrations](/docs/integrations.md): Official and community integrations for Task, including VS Code, JSON schemas, and other tools\n- [Taskfile Versions](/docs/taskfile-versions.md): How to use the Taskfile schema version to ensure users are using the correct versions of Task\n"

# %%
# making html based on md context
html_from_md = marko.convert(md_text)
html_from_md
# Out:
# '<h1>Task</h1>\n<blockquote>\n<p>The Modern Task Runner</p>\n</blockquote>\n<p>A fast, cross-platform build tool inspired by Make, designed for modern workflows.</p>\n<h2>Table of Contents</h2>\n<h3>Reference</h3>\n<ul>\n<li><a href="/docs/reference/schema.md">Taskfile Schema Reference</a>: A reference for the Taskfile schema</li>\n<li><a href="/docs/reference/environment.md">Environment Reference</a>: A reference for the Taskfile environment variables</li>\n<li><a href="/docs/reference/config.md">Configuration Reference</a>: Complete reference for the Task config files and env vars</li>\n<li><a href="/docs/reference/cli.md">Command Line Interface Reference</a>: Complete reference for Task CLI commands, flags, and exit codes</li>\n<li><a href="/docs/reference/templating.md">Templating Reference</a>: Comprehensive guide to Task\'s templating system with Go text/template, special variables, and available functions</li>\n<li><a href="/docs/reference/package.md">Package API Reference</a>: A reference for Task\'s Golang package API</li>\n</ul>\n<h3>Experiments</h3>\n<ul>\n<li><a href="/docs/experiments/env-precedence.md">Env Precedence (#1038)</a>: Experiment to change the precedence of environment variables in Task</li>\n<li><a href="/docs/experiments/gentle-force.md">Gentle Force (#1200)</a>: Experiment to modify the behavior of the --force flag in Task</li>\n<li><a href="/docs/experiments/remote-taskfiles.md">Remote Taskfiles (#1317)</a>: Experimentation for using Taskfiles stored in remote locations</li>\n</ul>\n<h3>Deprecations</h3>\n<ul>\n<li><a href="/docs/deprecations/completion-scripts.md">Completion Scripts</a>: Deprecation of direct completion scripts in Task’s Git directory</li>\n<li><a href="/docs/deprecations/template-functions.md">Template Functions</a>: Deprecation of some templating functions in Task, with guidance on their replacements.</li>\n<li><a href="/docs/deprecations/version-2-schema.md">Version 2 Schema (#1197)</a>: Deprecation of Taskfile schema version 2 and migration to version 3</li>\n</ul>\n<h3>Other</h3>\n<ul>\n<li><a href="/docs/deprecations/template.md">--- Template ---</a>: Template for documenting deprecated features in Task</li>\n<li><a href="/docs/experiments/template.md">--- Template ---</a></li>\n<li><a href="/docs/community.md">Community</a>: Task community contributions, installation methods, and integrations maintained by third parties</li>\n<li><a href="/docs/faq.md">FAQ</a>: Frequently asked questions about Task, including ETAs, shell limitations, and Windows compatibility</li>\n<li><a href="/docs/getting-started.md">Getting Started</a>: Guide for getting started with Task</li>\n<li><a href="/docs/guide.md">Guide</a></li>\n<li><a href="/docs/installation.md">Installation</a>: Installation methods for Task</li>\n<li><a href="/docs/integrations.md">Integrations</a>: Official and community integrations for Task, including VS Code, JSON schemas, and other tools</li>\n<li><a href="/docs/taskfile-versions.md">Taskfile Versions</a>: How to use the Taskfile schema version to ensure users are using the correct versions of Task</li>\n</ul>\n'

# %%
# final display looks like this
IPython.core.display.HTML(html_from_md)
# Out:
# <h1>Task</h1>
# <blockquote>
# <p>The Modern Task Runner</p>
# </blockquote>
# <p>A fast, cross-platform build tool inspired by Make, designed for modern workflows.</p>
# <h2>Table of Contents</h2>
# <h3>Reference</h3>
# <ul>
# <li><a href="/docs/reference/schema.md">Taskfile Schema Reference</a>: A reference for the Taskfile schema</li>
# <li><a href="/docs/reference/environment.md">Environment Reference</a>: A reference for the Taskfile environment variables</li>
# <li><a href="/docs/reference/config.md">Configuration Reference</a>: Complete reference for the Task config files and env vars</li>
# <li><a href="/docs/reference/cli.md">Command Line Interface Reference</a>: Complete reference for Task CLI commands, flags, and exit codes</li>
# <li><a href="/docs/reference/templating.md">Templating Reference</a>: Comprehensive guide to Task's templating system with Go text/template, special variables, and available functions</li>
# <li><a href="/docs/reference/package.md">Package API Reference</a>: A reference for Task's Golang package API</li>
# </ul>
# <h3>Experiments</h3>
# <ul>
# <li><a href="/docs/experiments/env-precedence.md">Env Precedence (#1038)</a>: Experiment to change the precedence of environment variables in Task</li>
# <li><a href="/docs/experiments/gentle-force.md">Gentle Force (#1200)</a>: Experiment to modify the behavior of the --force flag in Task</li>
# <li><a href="/docs/experiments/remote-taskfiles.md">Remote Taskfiles (#1317)</a>: Experimentation for using Taskfiles stored in remote locations</li>
# </ul>
# <h3>Deprecations</h3>
# <ul>
# <li><a href="/docs/deprecations/completion-scripts.md">Completion Scripts</a>: Deprecation of direct completion scripts in Task’s Git directory</li>
# <li><a href="/docs/deprecations/template-functions.md">Template Functions</a>: Deprecation of some templating functions in Task, with guidance on their replacements.</li>
# <li><a href="/docs/deprecations/version-2-schema.md">Version 2 Schema (#1197)</a>: Deprecation of Taskfile schema version 2 and migration to version 3</li>
# </ul>
# <h3>Other</h3>
# <ul>
# <li><a href="/docs/deprecations/template.md">--- Template ---</a>: Template for documenting deprecated features in Task</li>
# <li><a href="/docs/experiments/template.md">--- Template ---</a></li>
# <li><a href="/docs/community.md">Community</a>: Task community contributions, installation methods, and integrations maintained by third parties</li>
# <li><a href="/docs/faq.md">FAQ</a>: Frequently asked questions about Task, including ETAs, shell limitations, and Windows compatibility</li>
# <li><a href="/docs/getting-started.md">Getting Started</a>: Guide for getting started with Task</li>
# <li><a href="/docs/guide.md">Guide</a></li>
# <li><a href="/docs/installation.md">Installation</a>: Installation methods for Task</li>
# <li><a href="/docs/integrations.md">Integrations</a>: Official and community integrations for Task, including VS Code, JSON schemas, and other tools</li>
# <li><a href="/docs/taskfile-versions.md">Taskfile Versions</a>: How to use the Taskfile schema version to ensure users are using the correct versions of Task</li>
# </ul>

# %%
raw_text = bs4.BeautifulSoup(html_from_md).text



def sentence_prep(wordline):
    #wordline = wordline.strip()
    wordline = wordline.lower()
    wordline = wordline.replace(",", " COMMA ")
    wordline = wordline.replace(":", " DASH ")
    wordline = wordline.replace(";", " SEPARATOR ")
    wordline = wordline.replace("#", " HASHTAG ")
    wordline = wordline.replace('"', "''").replace("`", "'").replace("'", " UPPERCOMMA ")
    wordline = wordline.replace("\t", " TAB ")
    wordline = wordline.replace("\r", " RETURN ")
    wordline = wordline.replace("[", "(").replace("{", "(").replace("(", " BRACKETSTART ")
    wordline = wordline.replace("]", ")").replace("}", ")").replace(")", " BRACKETSTOP ")
    wordline = wordline.replace("\\", "/").replace("/", " SLASH ")
    wordline = wordline.replace("@", " AT ")
    wordline = wordline.replace("&", " AMPERSAND ")
    wordline = wordline.replace("|", " PIPE ")
    wordline = wordline.replace("~", " LAMBDA ")
    wordline = wordline.replace("*", " ASTERISK ")
    wordline = wordline.replace("^", " UPINDEX ")
    wordline = wordline.replace("%", " PERCENT ")
    wordline = wordline.replace("$", " DOLARSIGN ")
    wordline = wordline.replace("!", " SHOUT ")
    wordline = wordline.replace("?", " QUESTION ")
    wordline = wordline.replace("=", " EQUALS ")
    wordline = wordline.replace(".", " END ")
    wordline = wordline.replace("+", " PLUS ")
    wordline = wordline.replace("_", " FLOOR ")
    wordline = wordline.replace(">", " GREATER ")
    wordline = wordline.replace("<", " LESSER ")
    wordchain = [x.strip() for x in wordline.split(" ") if x.strip()]
    return wordchain

[sentence_prep(x.strip()) for x in raw_text.replace(".", "\n").split("\n") if x.strip()]
# Out:
# [['task'],
#  ['the', 'modern', 'task', 'runner'],
#  ['a',
#   'fast',
#   'COMMA',
#   'cross-platform',
#   'build',
#   'tool',
#   'inspired',
#   'by',
#   'make',
#   'COMMA',
#   'designed',
#   'for',
#   'modern',
#   'workflows'],
#  ['table', 'of', 'contents'],
#  ['reference'],
#  ['taskfile',
#   'schema',
#   'reference',
#   'DASH',
#   'a',
#   'reference',
#   'for',
#   'the',
#   'taskfile',
#   'schema'],
#  ['environment',
#   'reference',
#   'DASH',
#   'a',
#   'reference',
#   'for',
#   'the',
#   'taskfile',
#   'environment',
#   'variables'],
#  ['configuration',
#   'reference',
#   'DASH',
#   'complete',
#   'reference',
#   'for',
#   'the',
#   'task',
#   'config',
#   'files',
#   'and',
#   'env',
#   'vars'],
#  ['command',
#   'line',
#   'interface',
#   'reference',
#   'DASH',
#   'complete',
#   'reference',
#   'for',
#   'task',
#   'cli',
#   'commands',
#   'COMMA',
#   'flags',
#   'COMMA',
#   'and',
#   'exit',
#   'codes'],
#  ['templating',
#   'reference',
#   'DASH',
#   'comprehensive',
#   'guide',
#   'to',
#   'task',
#   'UPPERCOMMA',
#   's',
#   'templating',
#   'system',
#   'with',
#   'go',
#   'text',
#   'SLASH',
#   'template',
#   'COMMA',
#   'special',
#   'variables',
#   'COMMA',
#   'and',
#   'available',
#   'functions'],
#  ['package',
#   'api',
#   'reference',
#   'DASH',
#   'a',
#   'reference',
#   'for',
#   'task',
#   'UPPERCOMMA',
#   's',
#   'golang',
#   'package',
#   'api'],
#  ['experiments'],
#  ['env',
#   'precedence',
#   'BRACKETSTART',
#   'HASHTAG',
#   '1038',
#   'BRACKETSTOP',
#   'DASH',
#   'experiment',
#   'to',
#   'change',
#   'the',
#   'precedence',
#   'of',
#   'environment',
#   'variables',
#   'in',
#   'task'],
#  ['gentle',
#   'force',
#   'BRACKETSTART',
#   'HASHTAG',
#   '1200',
#   'BRACKETSTOP',
#   'DASH',
#   'experiment',
#   'to',
#   'modify',
#   'the',
#   'behavior',
#   'of',
#   'the',
#   '--force',
#   'flag',
#   'in',
#   'task'],
#  ['remote',
#   'taskfiles',
#   'BRACKETSTART',
#   'HASHTAG',
#   '1317',
#   'BRACKETSTOP',
#   'DASH',
#   'experimentation',
#   'for',
#   'using',
#   'taskfiles',
#   'stored',
#   'in',
#   'remote',
#   'locations'],
#  ['deprecations'],
#  ['completion',
#   'scripts',
#   'DASH',
#   'deprecation',
#   'of',
#   'direct',
#   'completion',
#   'scripts',
#   'in',
#   'task’s',
#   'git',
#   'directory'],
#  ['template',
#   'functions',
#   'DASH',
#   'deprecation',
#   'of',
#   'some',
#   'templating',
#   'functions',
#   'in',
#   'task',
#   'COMMA',
#   'with',
#   'guidance',
#   'on',
#   'their',
#   'replacements'],
#  ['version',
#   '2',
#   'schema',
#   'BRACKETSTART',
#   'HASHTAG',
#   '1197',
#   'BRACKETSTOP',
#   'DASH',
#   'deprecation',
#   'of',
#   'taskfile',
#   'schema',
#   'version',
#   '2',
#   'and',
#   'migration',
#   'to',
#   'version',
#   '3'],
#  ['other'],
#  ['---',
#   'template',
#   '---',
#   'DASH',
#   'template',
#   'for',
#   'documenting',
#   'deprecated',
#   'features',
#   'in',
#   'task'],
#  ['---', 'template', '---'],
#  ['community',
#   'DASH',
#   'task',
#   'community',
#   'contributions',
#   'COMMA',
#   'installation',
#   'methods',
#   'COMMA',
#   'and',
#   'integrations',
#   'maintained',
#   'by',
#   'third',
#   'parties'],
#  ['faq',
#   'DASH',
#   'frequently',
#   'asked',
#   'questions',
#   'about',
#   'task',
#   'COMMA',
#   'including',
#   'etas',
#   'COMMA',
#   'shell',
#   'limitations',
#   'COMMA',
#   'and',
#   'windows',
#   'compatibility'],
#  ['getting',
#   'started',
#   'DASH',
#   'guide',
#   'for',
#   'getting',
#   'started',
#   'with',
#   'task'],
#  ['guide'],
#  ['installation', 'DASH', 'installation', 'methods', 'for', 'task'],
#  ['integrations',
#   'DASH',
#   'official',
#   'and',
#   'community',
#   'integrations',
#   'for',
#   'task',
#   'COMMA',
#   'including',
#   'vs',
#   'code',
#   'COMMA',
#   'json',
#   'schemas',
#   'COMMA',
#   'and',
#   'other',
#   'tools'],
#  ['taskfile',
#   'versions',
#   'DASH',
#   'how',
#   'to',
#   'use',
#   'the',
#   'taskfile',
#   'schema',
#   'version',
#   'to',
#   'ensure',
#   'users',
#   'are',
#   'using',
#   'the',
#   'correct',
#   'versions',
#   'of',
#   'task']]

# %%
replace_matrix = {
    "0": "ZERO",
    "1": "JEDEN",
    "2": "DWA",
    "3": "TRZY",
    "4": "CZTERY",
    "5": "PIECI",
    "6": "SZESCI",
    "7": "SIEDEM",
    "8": "OSIEM",
    "9": "DZIEWIECI",
    ",": "PRZECINEK",
    "-": "DASZ",
    ":": "DWUKROP",
    ";": "SEPARATOR",
    "#":"HASZTAG",
    #'"': "''",
    '"':"SKOKPRZECIN SKOKPRZECIN",
    "`":"SKOKPRZECIN",
    "'":"SKOKPRZECIN",
    #.replace("`", "'").replace("'":"UPPERCOMMA",
    "\t":"TAB",
    "\r":"WRACAJ",
    # "[":"BRACKETSTART",
    # "{":"BRACKETSTART",
    # "(":"BRACKETSTART",
    "[":"STARTNAWIAS",
    "{":"STARTNAWIAS",
    "(":"STARTNAWIAS",
    #"[", "(").replace("{", "(").replace("(":"BRACKETSTART",
    #"]",",").replace("}",",").replace(")":"BRACKETSTOP",
    #"\\", "/").replace("/":"SLASH",
    # "]":"BRACKETSTOP",
    # "}":"BRACKETSTOP",
    # ")":"BRACKETSTOP",
    "]":"STOPNAWIAS",
    "}":"STOPNAWIAS",
    ")":"STOPNAWIAS",
    "\\":"SLESZ",
    "/":"SLESZ",
    #",").replace("}",",").replace(")":"BRACKETSTOP",
    #"\\", "/").replace("/":"SLASH",
    "@":"MAUPA",
    "&":"AMPERSAND",
    "|":"PIPE",
    "~":"LAMBDA",
    "*":"ASTERISK",
    "^":"UPINDEX",
    "%":"PERCENT",
    "$":"DOLARSIGN",
    "!":"SHOUT",
    "?":"QUESTION",
    "=":"EQUALS",
    ".":"END",
    "+":"PLUS",
    "_":"FLOOR",
    ">":"GREATER",
    "<":"LESSER",
}

def sentence_prep(wordline):
    global replace_matrix
    #wordline = wordline.strip()
    wordline = wordline.lower()
    for replacer in replace_matrix:
        wordline = wordline.replace(replacer, " "+replace_matrix[replacer]+" ")
    # wordline = wordline.replace(",", " COMMA ")
    # wordline = wordline.replace(":", " DASH ")
    # wordline = wordline.replace(";", " SEPARATOR ")
    # wordline = wordline.replace("#", " HASHTAG ")
    # wordline = wordline.replace('"', "''").replace("`", "'").replace("'", " UPPERCOMMA ")
    # wordline = wordline.replace("\t", " TAB ")
    # wordline = wordline.replace("\r", " RETURN ")
    # wordline = wordline.replace("[", "(").replace("{", "(").replace("(", " BRACKETSTART ")
    # wordline = wordline.replace("]", ")").replace("}", ")").replace(")", " BRACKETSTOP ")
    # wordline = wordline.replace("\\", "/").replace("/", " SLASH ")
    # wordline = wordline.replace("@", " AT ")
    # wordline = wordline.replace("&", " AMPERSAND ")
    # wordline = wordline.replace("|", " PIPE ")
    # wordline = wordline.replace("~", " LAMBDA ")
    # wordline = wordline.replace("*", " ASTERISK ")
    # wordline = wordline.replace("^", " UPINDEX ")
    # wordline = wordline.replace("%", " PERCENT ")
    # wordline = wordline.replace("$", " DOLARSIGN ")
    # wordline = wordline.replace("!", " SHOUT ")
    # wordline = wordline.replace("?", " QUESTION ")
    # wordline = wordline.replace("=", " EQUALS ")
    # wordline = wordline.replace(".", " END ")
    # wordline = wordline.replace("+", " PLUS ")
    # wordline = wordline.replace("_", " FLOOR ")
    # wordline = wordline.replace(">", " GREATER ")
    # wordline = wordline.replace("<", " LESSER ")
    wordchain = [x.strip() for x in wordline.split(" ") if x.strip()]
    return wordchain

def text_to_tokenchain_sentences(textstr):
    textstr = textstr.replace(".", "\n")
    sentences = textstr.split("\n")
    return [sentence_prep(sentence_str.strip()) for sentence_str in sentences if sentence_str.strip()]


text_to_tokenchain_sentences(raw_text)
# Out:
# [['task'],
#  ['the', 'modern', 'task', 'runner'],
#  ['a',
#   'fast',
#   'PRZECINEK',
#   'cross',
#   'DASZ',
#   'platform',
#   'build',
#   'tool',
#   'inspired',
#   'by',
#   'make',
#   'PRZECINEK',
#   'designed',
#   'for',
#   'modern',
#   'workflows'],
#  ['table', 'of', 'contents'],
#  ['reference'],
#  ['taskfile',
#   'schema',
#   'reference',
#   'DWUKROP',
#   'a',
#   'reference',
#   'for',
#   'the',
#   'taskfile',
#   'schema'],
#  ['environment',
#   'reference',
#   'DWUKROP',
#   'a',
#   'reference',
#   'for',
#   'the',
#   'taskfile',
#   'environment',
#   'variables'],
#  ['configuration',
#   'reference',
#   'DWUKROP',
#   'complete',
#   'reference',
#   'for',
#   'the',
#   'task',
#   'config',
#   'files',
#   'and',
#   'env',
#   'vars'],
#  ['command',
#   'line',
#   'interface',
#   'reference',
#   'DWUKROP',
#   'complete',
#   'reference',
#   'for',
#   'task',
#   'cli',
#   'commands',
#   'PRZECINEK',
#   'flags',
#   'PRZECINEK',
#   'and',
#   'exit',
#   'codes'],
#  ['templating',
#   'reference',
#   'DWUKROP',
#   'comprehensive',
#   'guide',
#   'to',
#   'task',
#   'SKOKPRZECIN',
#   's',
#   'templating',
#   'system',
#   'with',
#   'go',
#   'text',
#   'SLESZ',
#   'template',
#   'PRZECINEK',
#   'special',
#   'variables',
#   'PRZECINEK',
#   'and',
#   'available',
#   'functions'],
#  ['package',
#   'api',
#   'reference',
#   'DWUKROP',
#   'a',
#   'reference',
#   'for',
#   'task',
#   'SKOKPRZECIN',
#   's',
#   'golang',
#   'package',
#   'api'],
#  ['experiments'],
#  ['env',
#   'precedence',
#   'STARTNAWIAS',
#   'HASZTAG',
#   'JEDEN',
#   'ZERO',
#   'TRZY',
#   'OSIEM',
#   'STOPNAWIAS',
#   'DWUKROP',
#   'experiment',
#   'to',
#   'change',
#   'the',
#   'precedence',
#   'of',
#   'environment',
#   'variables',
#   'in',
#   'task'],
#  ['gentle',
#   'force',
#   'STARTNAWIAS',
#   'HASZTAG',
#   'JEDEN',
#   'DWA',
#   'ZERO',
#   'ZERO',
#   'STOPNAWIAS',
#   'DWUKROP',
#   'experiment',
#   'to',
#   'modify',
#   'the',
#   'behavior',
#   'of',
#   'the',
#   'DASZ',
#   'DASZ',
#   'force',
#   'flag',
#   'in',
#   'task'],
#  ['remote',
#   'taskfiles',
#   'STARTNAWIAS',
#   'HASZTAG',
#   'JEDEN',
#   'TRZY',
#   'JEDEN',
#   'SIEDEM',
#   'STOPNAWIAS',
#   'DWUKROP',
#   'experimentation',
#   'for',
#   'using',
#   'taskfiles',
#   'stored',
#   'in',
#   'remote',
#   'locations'],
#  ['deprecations'],
#  ['completion',
#   'scripts',
#   'DWUKROP',
#   'deprecation',
#   'of',
#   'direct',
#   'completion',
#   'scripts',
#   'in',
#   'task’s',
#   'git',
#   'directory'],
#  ['template',
#   'functions',
#   'DWUKROP',
#   'deprecation',
#   'of',
#   'some',
#   'templating',
#   'functions',
#   'in',
#   'task',
#   'PRZECINEK',
#   'with',
#   'guidance',
#   'on',
#   'their',
#   'replacements'],
#  ['version',
#   'DWA',
#   'schema',
#   'STARTNAWIAS',
#   'HASZTAG',
#   'JEDEN',
#   'JEDEN',
#   'DZIEWIECI',
#   'SIEDEM',
#   'STOPNAWIAS',
#   'DWUKROP',
#   'deprecation',
#   'of',
#   'taskfile',
#   'schema',
#   'version',
#   'DWA',
#   'and',
#   'migration',
#   'to',
#   'version',
#   'TRZY'],
#  ['other'],
#  ['DASZ',
#   'DASZ',
#   'DASZ',
#   'template',
#   'DASZ',
#   'DASZ',
#   'DASZ',
#   'DWUKROP',
#   'template',
#   'for',
#   'documenting',
#   'deprecated',
#   'features',
#   'in',
#   'task'],
#  ['DASZ', 'DASZ', 'DASZ', 'template', 'DASZ', 'DASZ', 'DASZ'],
#  ['community',
#   'DWUKROP',
#   'task',
#   'community',
#   'contributions',
#   'PRZECINEK',
#   'installation',
#   'methods',
#   'PRZECINEK',
#   'and',
#   'integrations',
#   'maintained',
#   'by',
#   'third',
#   'parties'],
#  ['faq',
#   'DWUKROP',
#   'frequently',
#   'asked',
#   'questions',
#   'about',
#   'task',
#   'PRZECINEK',
#   'including',
#   'etas',
#   'PRZECINEK',
#   'shell',
#   'limitations',
#   'PRZECINEK',
#   'and',
#   'windows',
#   'compatibility'],
#  ['getting',
#   'started',
#   'DWUKROP',
#   'guide',
#   'for',
#   'getting',
#   'started',
#   'with',
#   'task'],
#  ['guide'],
#  ['installation', 'DWUKROP', 'installation', 'methods', 'for', 'task'],
#  ['integrations',
#   'DWUKROP',
#   'official',
#   'and',
#   'community',
#   'integrations',
#   'for',
#   'task',
#   'PRZECINEK',
#   'including',
#   'vs',
#   'code',
#   'PRZECINEK',
#   'json',
#   'schemas',
#   'PRZECINEK',
#   'and',
#   'other',
#   'tools'],
#  ['taskfile',
#   'versions',
#   'DWUKROP',
#   'how',
#   'to',
#   'use',
#   'the',
#   'taskfile',
#   'schema',
#   'version',
#   'to',
#   'ensure',
#   'users',
#   'are',
#   'using',
#   'the',
#   'correct',
#   'versions',
#   'of',
#   'task']]

# %%
import re
import zlib

glossary = dict()

def paratangle(data):
    return [
        hex(zlib.adler32(data.encode("utf-8")))[2:],
        hex(zlib.crc32(data.encode("utf-8")))[2:]
    ]

def check_a12y(testdata):
    acsii_letter_pattern = '[a-zA-Z]'
    check = re.compile(acsii_letter_pattern)
    return (check.match(testdata[0]) and check.match(testdata[-1]))

def a12y(input_str):
    global glossary
    output_str = []
    if len(input_str) and check_a12y(input_str):
        output_str = [
            input_str[0],
            str(len(input_str)),
            input_str[-1]
        ]

    else:
        output_str = [
            "0",
            "-",
            hex(ord(input_str[0]))[2:],
            "-",
            hex(len(input_str))[2:],
            "-",
            hex(ord(input_str[-1]))[2:]
        ]
    keystr = "".join(output_str)
    if not keystr in glossary:
        glossary[keystr]=list()
    
    if not input_str in glossary[keystr]:
        glossary[keystr].append(input_str)
    if glossary[keystr].index(input_str) == 0:
        return f"{keystr}"
    else: 
        return f"{keystr}{glossary[keystr].index(input_str)}"

ratfile = """
@glossaries
#strmode
$WORDS
# !pipe_meanings
"""
def spelling_rat(keystr, elements):
    d = [
        ".a12y_entry",
        f"${keystr}",
        "="+"\n+".join(elements),
        #f"%{len(elements)}",
        f":{"-".join(paratangle(keystr))}",
        "*"+"\n*".join(["-".join(paratangle(elem)) for elem in elements]),
        ""
    ]
    return "\n".join(d)

tmp_text = [ "\n+".join([a12y(y) for y in x]) for x in text_to_tokenchain_sentences(raw_text)]

for keyword in glossary:
    ratfile +=spelling_rat(keyword, glossary[keyword])

ratfile += """
@conversations
#intmode
$spellindex
=0
#strmode
.build_sentence
$sentence
=WORDS.A12Y.
"""

sentence_sep = """
# !talk_sentence
#intmode
$spellindex
+1
#strmode
.build_sentence
$sentence
=WORDS.A12Y.\n
"""
ratfile += sentence_sep.join(tmp_text)
ratfile += """
# !talk_sentence
<save
"""
print("\t md_text:", len(md_text))
print("\t html_text:", len(html_from_md))
print("\t html_text:", len(raw_text))
print("\t RAT Size:", len(ratfile))
print("\t RAT Lines:", len(ratfile.split("\n")))
print()
print(ratfile)
# Out:
# 	 md_text: 2606
# 	 html_text: 3085
# 	 html_text: 1877
# 	 RAT Size: 12743
# 	 RAT Lines: 1283
#
#
# @glossaries
# #strmode
# $WORDS
# !pipe_meanings
# .a12y_entry
# $t4k
# =task
# :2320114-cdf352b9
# *44801b4-527edb25
# .a12y_entry
# $t3e
# =the
# :22a010d-650ae979
# *2940142-3c456de6
# .a12y_entry
# $m6n
# =modern
# :2240112-9c585c4b
# *8d00286-5391630f
# .a12y_entry
# $r6r
# =runner
# :237011b-9f23e449
# *939029b-f92b8b3e
# .a12y_entry
# $a1a
# =a
# :1e900f4-4abc2e79
# *620062-e8b7be43
# .a12y_entry
# $f4t
# =fast
# :211010f-5f592852
# *41901af-256649c4
# .a12y_entry
# $P9K
# =PRZECINEK
# :1b000d5-7c77e200
# *daf02ac-b4233af9
# .a12y_entry
# $c5s
# =cross
# +codes
# :209010c-deed4e5b
# *662022b-57131439
# *619020f-e5adc14d
# .a12y_entry
# $D4Z
# =DASZ
# :19100d3-b846b713
# *2d70133-5e4241fc
# .a12y_entry
# $p8m
# =platform
# :2300116-8f2c105c
# *f3c0366-3952d0cb
# .a12y_entry
# $b5d
# =build
# :1f700fc-5cfca1ab
# *63a0211-bda0f2db
# .a12y_entry
# $t4l
# =tool
# :2330115-5397c71a
# *46b01bf-20f33ed1
# .a12y_entry
# $i8d
# =inspired
# :2120106-e5073007
# *f5c035f-4665f2f5
# .a12y_entry
# $b2y
# =by
# :206010e-70bb5bb5
# *13f00dc-3fcbd242
# .a12y_entry
# $m4e
# =make
# :2170107-39bce741
# *416019f-1acc766e
# .a12y_entry
# $d8d
# =designed
# :2030101-eddfa354
# *ebe0344-47746b0a
# .a12y_entry
# $f3r
# =for
# :20d010c-f97b1ba0
# *2850148-ef7509f8
# .a12y_entry
# $w9s
# =workflows
# :24d0124-69770afb
# *13ac03ef-efbfbfc2
# .a12y_entry
# $t5e
# =table
# :22e010f-33504eff
# *6300209-f6298f46
# .a12y_entry
# $o2f
# =of
# :21a0108-f56bc513
# *14600d6-76da1fa
# .a12y_entry
# $c8s
# =contents
# +commands
# :20f010f-6b433016
# *f3a036f-b4fa1177
# *ee10353-9a3e132c
# .a12y_entry
# $r9e
# =reference
# :2300111-9b687d41
# *129e03b0-aea34913
# .a12y_entry
# $t8e
# =taskfile
# +template
# :2340112-86fe30b2
# *f280354-ae76d76d
# *f49035d-97601f83
# .a12y_entry
# $s6a
# =schema
# :229010b-1a5fcfa0
# *8b10272-b88e4152
# .a12y_entry
# $D7P
# =DWUKROP
# :18d00cc-73be0dce
# *8a6022d-f3f7d13c
# .a12y_entry
# $e11t
# =environment
# :301013c-9920e51d
# *1c2d04b6-4626de22
# .a12y_entry
# $v9s
# =variables
# :24a0123-68b560cc
# *12b903ba-88cb7d11
# .a12y_entry
# $c13n
# =configuration
# :2f70136-731f2139
# *26020579-a5e2a5d7
# .a12y_entry
# $c8e
# =complete
# :2010101-9f978547
# *f13035a-4267d023
# .a12y_entry
# $c6g
# =config
# :1ff0101-ef1ac9e5
# *8a60277-d48a2f7c
# .a12y_entry
# $f5s
# =files
# +flags
# :212010f-d8268cb0
# *6280214-6354059
# *617020e-b0541ba
# .a12y_entry
# $a3d
# =and
# :1f000f9-8e0b874
# *2660134-7f59b6d
# .a12y_entry
# $e3v
# =env
# :20e010f-fc5061e0
# *284014a-f34542f9
# .a12y_entry
# $v4s
# =vars
# :240011e-dd1b1e81
# *45601bd-f200bab9
# .a12y_entry
# $c7d
# =command
# :1fe00ff-6f08a91e
# *b8e02e0-8ecaead4
# .a12y_entry
# $l4e
# =line
# :2140106-387e8d76
# *43001a9-d114b4f6
# .a12y_entry
# $i9e
# =interface
# :2150108-8b1b31d0
# *12d403b2-34f4ecdd
# .a12y_entry
# $c3i
# =cli
# :1fb0100-75d510a7
# *26d0139-48f6513c
# .a12y_entry
# $e4t
# =exit
# :20e010e-5d1f960b
# *44601bb-9409840e
# .a12y_entry
# $t10g
# =templating
# :32e013d-ec20a578
# *17520436-fdcd0854
# .a12y_entry
# $c13e
# =comprehensive
# :2ee012d-e4cdf8b1
# *26350579-718ff97d
# .a12y_entry
# $g5e
# =guide
# :2070102-2d3053d6
# *644020f-ca9ec735
# .a12y_entry
# $t2o
# =to
# :2320116-9cc43126
# *15900e4-d787d2c4
# .a12y_entry
# $S11N
# =SKOKPRZECIN
# :2930104-8a6c9bd2
# *14440354-e7a4709f
# .a12y_entry
# $s1s
# =s
# :2310118-a6a7282f
# *740074-1b0ecf0b
# .a12y_entry
# $s6m
# =system
# :2350117-13e9838b
# *97402a6-c94d118b
# .a12y_entry
# $w4h
# =with
# :2380114-56bcbd5a
# *46b01bd-9890e20e
# .a12y_entry
# $g2o
# =go
# :20b0109-82a42c0f
# *13f00d7-b6689356
# .a12y_entry
# $t4t
# =text
# :23b011d-40fb5f4c
# *46701c6-3b8ba7c7
# .a12y_entry
# $S5Z
# =SLESZ
# :1c000e3-b83433a7
# *4a30192-42a5cd5
# .a12y_entry
# $s7l
# =special
# :2360117-7df5825c
# *bba02e2-4c6b3fe3
# .a12y_entry
# $a9e
# =available
# :1fd0100-85086068
# *124203a2-a58fa485
# .a12y_entry
# $f9s
# =functions
# :21a0113-7493c3bc
# *131f03da-43ac2d0c
# .a12y_entry
# $p7e
# =package
# :226010d-66f84a1
# *b4e02cd-de686795
# .a12y_entry
# $a3i
# =api
# :1f500fe-7651c4c9
# *26f013b-ad05d80f
# .a12y_entry
# $g6g
# =golang
# :20b0105-e8136139
# *8b10279-af1c25a3
# .a12y_entry
# $e11s
# =experiments
# :300013b-74470be
# *1c1804b5-3e7272f3
# .a12y_entry
# $p10e
# =precedence
# :31c0137-8d4c5303
# *16a4040f-e0f1fdd6
# .a12y_entry
# $S11S
# =STARTNAWIAS
# :2980109-e96af70b
# *142e0352-5104e71b
# .a12y_entry
# $H7G
# =HASZTAG
# :19000c7-f977716d
# *8510213-9fe04b6f
# .a12y_entry
# $J5N
# =JEDEN
# :19900ce-b1197f25
# *42f0167-1352ed31
# .a12y_entry
# $Z4O
# =ZERO
# :1c800de-c323dd82
# *32e0141-9d4b1c26
# .a12y_entry
# $T4Y
# =TRZY
# :1c000e2-3d6945d9
# *357015a-58f0e1b9
# .a12y_entry
# $O5M
# =OSIEM
# :1a700d2-2edbec74
# *48e017e-3f11a8eb
# .a12y_entry
# $S10S
# =STOPNAWIAS
# :2960108-f071c64a
# *1109030a-2f2f990a
# .a12y_entry
# $e10t
# =experiment
# :2ff013b-803bd45c
# *17630442-136f58b2
# .a12y_entry
# $c6e
# =change
# :1fd00ff-114a8c9
# *8610267-4057fe20
# .a12y_entry
# $i2n
# =in
# :210010a-ff3d3193
# *14200d8-5fec8e4e
# .a12y_entry
# $g6e
# =gentle
# :2090103-61d0015
# *8ba0280-897097bc
# .a12y_entry
# $f5e
# =force
# :2040101-2cf239e1
# *6400210-97688328
# .a12y_entry
# $D3A
# =DWA
# :17600b9-7d62e838
# *1be00dd-7cf3469b
# .a12y_entry
# $m6y
# =modify
# :22f011d-1f8bd98c
# *8cf0289-f7f6c8f9
# .a12y_entry
# $b8r
# =behavior
# :20b010d-1d866ab7
# *e930351-3baba0b0
# .a12y_entry
# $f4g
# =flag
# :2040102-dbe7698c
# *409019b-d1f4eb9a
# .a12y_entry
# $r6e
# =remote
# :22a010e-1cf0618e
# *8f9028d-5ab67fb2
# .a12y_entry
# $t9s
# =taskfiles
# :2440121-6b31b4a2
# *12ef03c7-28a3a439
# .a12y_entry
# $S6M
# =SIEDEM
# :1b500d7-10cae5a3
# *61c01b8-3001eabc
# .a12y_entry
# $e15n
# =experimentation
# :303013a-2ed963
# *32e9065d-cf9ee405
# .a12y_entry
# $u5g
# =using
# :2330112-dc9c45e4
# *6980227-e134d5ad
# .a12y_entry
# $s6d
# =stored
# :22c010e-6a353b2f
# *93c0292-5643f90b
# .a12y_entry
# $l9s
# =locations
# :22c0119-7904466a
# *12cc03cd-17e64aba
# .a12y_entry
# $d12s
# =deprecations
# :2fe013b-94d54418
# *201c0502-8366f5c5
# .a12y_entry
# $c10n
# =completion
# :2f10133-583272fa
# *171f043b-38d6377e
# .a12y_entry
# $s7s
# =scripts
# +schemas
# :23d011e-f0fd8fa9
# *c070309-dd1e973e
# *b9602e5-9ed37192
# .a12y_entry
# $d11n
# =deprecation
# :2f70135-dcfe7b02
# *1b1a048f-ba1a7242
# .a12y_entry
# $d6t
# =direct
# :20f010f-6eeb9ebe
# *89c027c-2017154e
# .a12y_entry
# $t6s
# =task’s
# :23e011e-eca9a86d
# *11c50422-f761bd87
# .a12y_entry
# $g3t
# =git
# :212010f-11dad4a2
# *27e0145-518e617c
# .a12y_entry
# $d9y
# =directory
# :21a0117-97c2fecc
# *12ba03d6-467844da
# .a12y_entry
# $s4e
# =some
# :229010d-2f04693b
# *45c01b5-f6cedc4e
# .a12y_entry
# $g8e
# =guidance
# :20d0105-989e2d9b
# *ed60341-f0cedda7
# .a12y_entry
# $o2n
# =on
# :2220110-fbb04d21
# *14e00de-9b629c8
# .a12y_entry
# $t5r
# =their
# :23b011c-b083cb38
# *65c021d-70caa7cb
# .a12y_entry
# $r12s
# =replacements
# :3360149-e1a74c5b
# *205c0504-8d53b271
# .a12y_entry
# $v7n
# =version
# :241011c-9530219b
# *c2c0307-bf1cd3c3
# .a12y_entry
# $D9I
# =DZIEWIECI
# :18a00c7-89568880
# *d4f029e-e1bdac6b
# .a12y_entry
# $m9n
# =migration
# :22a0115-1bc04084
# *12df03cb-c31cb5c2
# .a12y_entry
# $o5r
# =other
# :22c0117-a0f087a9
# *6740223-d9583520
# .a12y_entry
# $d11g
# =documenting
# :2f0012e-a522c3a6
# *1b9d049e-35912668
# .a12y_entry
# $d10d
# =deprecated
# :2eb012a-2530a35d
# *16780412-fe49a138
# .a12y_entry
# $f8s
# =features
# :2180112-6d88f2fd
# *eec0360-bfc0dc13
# .a12y_entry
# $c9y
# =community
# :2170116-928de849
# *132203e6-1b604033
# .a12y_entry
# $c13s
# =contributions
# :2fc013b-10194de0
# *26c40594-76391efe
# .a12y_entry
# $i12n
# =installation
# :30d013b-5b9f01c
# *21040513-1cba6ab1
# .a12y_entry
# $m7s
# =methods
# :22b0118-e64501d3
# *bcc02f5-56e2f769
# .a12y_entry
# $i12s
# =integrations
# :3120140-66bf9cc5
# *20e70518-7c2e6caa
# .a12y_entry
# $m10d
# =maintained
# :30f0133-5838ecd7
# *16b8041b-fa758b53
# .a12y_entry
# $t5d
# =third
# :22d010e-44577e69
# *66c021c-24322064
# .a12y_entry
# $p7s
# =parties
# :234011b-f2bb31f0
# *bdf02f9-43631805
# .a12y_entry
# $f3q
# =faq
# :20c010b-60724a1a
# *2680139-e8ff75cc
# .a12y_entry
# $f10y
# =frequently
# :3080141-ec3f070f
# *17630450-519f4b92
# .a12y_entry
# $a5d
# =asked
# :1f400fb-5eba1ff2
# *6250209-d2db8f0
# .a12y_entry
# $q9s
# =questions
# :23b011e-6dfa7649
# *13a303ec-8adc54d5
# .a12y_entry
# $a5t
# =about
# :204010b-430d0f96
# *61d021c-b5f422e3
# .a12y_entry
# $i9g
# =including
# :217010a-651550fc
# *12be03be-fc184517
# .a12y_entry
# $e4s
# =etas
# :20d010d-c37b03a8
# *42901ae-cbae62c1
# .a12y_entry
# $s5l
# =shell
# :2320115-4fc3e0de
# *6570219-4592b2fd
# .a12y_entry
# $l11s
# =limitations
# :31c0142-7a4c3f34
# *1bdc04ae-9e397b39
# .a12y_entry
# $w7s
# =windows
# :2490122-f7f42775
# *c22030c-e3e7859b
# .a12y_entry
# $c13y
# =compatibility
# :3020141-f0cca4fe
# *25e4057b-73cc2864
# .a12y_entry
# $g7g
# =getting
# :20d0106-f1085078
# *bc802f3-ce50045
# .a12y_entry
# $s7d
# =started
# :22e010f-732e0a6e
# *c1b02f8-b49696da
# .a12y_entry
# $o8l
# =official
# :22c0114-ef51c487
# *eb0033e-9877320d
# .a12y_entry
# $v2s
# =vs
# :23c011c-8b41b907
# *16100ea-f1b0ec09
# .a12y_entry
# $c4e
# =code
# :1f900fd-3322ca4b
# *40a019c-77153098
# .a12y_entry
# $j4n
# =json
# :217010d-ab21284c
# *45101bb-6b072545
# .a12y_entry
# $t5s
# =tools
# :23c011d-c784fbae
# *69d0232-eafade77
# .a12y_entry
# $v8s
# =versions
# :2480122-71ae518d
# *fa6037a-19dc40d2
# .a12y_entry
# $h3w
# =how
# :2180113-838fc225
# *290014f-9581d07d
# .a12y_entry
# $u3e
# =use
# :22d010e-64c8834e
# *2ad014e-94b1cc4b
# .a12y_entry
# $e6e
# =ensure
# :2030101-599d47b
# *8fe0293-c498dd0c
# .a12y_entry
# $u5s
# =users
# :23f011e-c6469199
# *6a00233-1483a5e9
# .a12y_entry
# $a3e
# =are
# :1f100fa-7fe788e2
# *26f0139-9685f6a6
# .a12y_entry
# $c7t
# =correct
# :20e010f-72bfb97a
# *bc102f3-cb106bbb
#
# @conversations
# #intmode
# $spellindex
# =0
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
# t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t3e
# +m6n
# +t4k
# +r6r
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# a1a
# +f4t
# +P9K
# +c5s
# +D4Z
# +p8m
# +b5d
# +t4l
# +i8d
# +b2y
# +m4e
# +P9K
# +d8d
# +f3r
# +m6n
# +w9s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t5e
# +o2f
# +c8s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# r9e
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t8e
# +s6a
# +r9e
# +D7P
# +a1a
# +r9e
# +f3r
# +t3e
# +t8e
# +s6a
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# e11t
# +r9e
# +D7P
# +a1a
# +r9e
# +f3r
# +t3e
# +t8e
# +e11t
# +v9s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# c13n
# +r9e
# +D7P
# +c8e
# +r9e
# +f3r
# +t3e
# +t4k
# +c6g
# +f5s
# +a3d
# +e3v
# +v4s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# c7d
# +l4e
# +i9e
# +r9e
# +D7P
# +c8e
# +r9e
# +f3r
# +t4k
# +c3i
# +c8s1
# +P9K
# +f5s1
# +P9K
# +a3d
# +e4t
# +c5s1
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t10g
# +r9e
# +D7P
# +c13e
# +g5e
# +t2o
# +t4k
# +S11N
# +s1s
# +t10g
# +s6m
# +w4h
# +g2o
# +t4t
# +S5Z
# +t8e1
# +P9K
# +s7l
# +v9s
# +P9K
# +a3d
# +a9e
# +f9s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# p7e
# +a3i
# +r9e
# +D7P
# +a1a
# +r9e
# +f3r
# +t4k
# +S11N
# +s1s
# +g6g
# +p7e
# +a3i
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# e11s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# e3v
# +p10e
# +S11S
# +H7G
# +J5N
# +Z4O
# +T4Y
# +O5M
# +S10S
# +D7P
# +e10t
# +t2o
# +c6e
# +t3e
# +p10e
# +o2f
# +e11t
# +v9s
# +i2n
# +t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# g6e
# +f5e
# +S11S
# +H7G
# +J5N
# +D3A
# +Z4O
# +Z4O
# +S10S
# +D7P
# +e10t
# +t2o
# +m6y
# +t3e
# +b8r
# +o2f
# +t3e
# +D4Z
# +D4Z
# +f5e
# +f4g
# +i2n
# +t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# r6e
# +t9s
# +S11S
# +H7G
# +J5N
# +T4Y
# +J5N
# +S6M
# +S10S
# +D7P
# +e15n
# +f3r
# +u5g
# +t9s
# +s6d
# +i2n
# +r6e
# +l9s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# d12s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# c10n
# +s7s
# +D7P
# +d11n
# +o2f
# +d6t
# +c10n
# +s7s
# +i2n
# +t6s
# +g3t
# +d9y
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t8e1
# +f9s
# +D7P
# +d11n
# +o2f
# +s4e
# +t10g
# +f9s
# +i2n
# +t4k
# +P9K
# +w4h
# +g8e
# +o2n
# +t5r
# +r12s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# v7n
# +D3A
# +s6a
# +S11S
# +H7G
# +J5N
# +J5N
# +D9I
# +S6M
# +S10S
# +D7P
# +d11n
# +o2f
# +t8e
# +s6a
# +v7n
# +D3A
# +a3d
# +m9n
# +t2o
# +v7n
# +T4Y
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# o5r
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# D4Z
# +D4Z
# +D4Z
# +t8e1
# +D4Z
# +D4Z
# +D4Z
# +D7P
# +t8e1
# +f3r
# +d11g
# +d10d
# +f8s
# +i2n
# +t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# D4Z
# +D4Z
# +D4Z
# +t8e1
# +D4Z
# +D4Z
# +D4Z
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# c9y
# +D7P
# +t4k
# +c9y
# +c13s
# +P9K
# +i12n
# +m7s
# +P9K
# +a3d
# +i12s
# +m10d
# +b2y
# +t5d
# +p7s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# f3q
# +D7P
# +f10y
# +a5d
# +q9s
# +a5t
# +t4k
# +P9K
# +i9g
# +e4s
# +P9K
# +s5l
# +l11s
# +P9K
# +a3d
# +w7s
# +c13y
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# g7g
# +s7d
# +D7P
# +g5e
# +f3r
# +g7g
# +s7d
# +w4h
# +t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# g5e
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# i12n
# +D7P
# +i12n
# +m7s
# +f3r
# +t4k
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# i12s
# +D7P
# +o8l
# +a3d
# +c9y
# +i12s
# +f3r
# +t4k
# +P9K
# +i9g
# +v2s
# +c4e
# +P9K
# +j4n
# +s7s1
# +P9K
# +a3d
# +o5r
# +t5s
# !talk_sentence
# #intmode
# $spellindex
# +1
# #strmode
# .build_sentence
# $sentence
# =WORDS.A12Y.
#
# t8e
# +v8s
# +D7P
# +h3w
# +t2o
# +u3e
# +t3e
# +t8e
# +s6a
# +v7n
# +t2o
# +e6e
# +u5s
# +a3e
# +u5g
# +t3e
# +c7t
# +v8s
# +o2f
# +t4k
# !talk_sentence
# <save

# %%
glossary
# Out:
# {'t4k': ['task'],
#  't3e': ['the'],
#  'm6n': ['modern'],
#  'r6r': ['runner'],
#  'a1a': ['a'],
#  'f4t': ['fast'],
#  'P9K': ['PRZECINEK'],
#  'c5s': ['cross', 'codes'],
#  'D4Z': ['DASZ'],
#  'p8m': ['platform'],
#  'b5d': ['build'],
#  't4l': ['tool'],
#  'i8d': ['inspired'],
#  'b2y': ['by'],
#  'm4e': ['make'],
#  'd8d': ['designed'],
#  'f3r': ['for'],
#  'w9s': ['workflows'],
#  't5e': ['table'],
#  'o2f': ['of'],
#  'c8s': ['contents', 'commands'],
#  'r9e': ['reference'],
#  't8e': ['taskfile', 'template'],
#  's6a': ['schema'],
#  'D7P': ['DWUKROP'],
#  'e11t': ['environment'],
#  'v9s': ['variables'],
#  'c13n': ['configuration'],
#  'c8e': ['complete'],
#  'c6g': ['config'],
#  'f5s': ['files', 'flags'],
#  'a3d': ['and'],
#  'e3v': ['env'],
#  'v4s': ['vars'],
#  'c7d': ['command'],
#  'l4e': ['line'],
#  'i9e': ['interface'],
#  'c3i': ['cli'],
#  'e4t': ['exit'],
#  't10g': ['templating'],
#  'c13e': ['comprehensive'],
#  'g5e': ['guide'],
#  't2o': ['to'],
#  'S11N': ['SKOKPRZECIN'],
#  's1s': ['s'],
#  's6m': ['system'],
#  'w4h': ['with'],
#  'g2o': ['go'],
#  't4t': ['text'],
#  'S5Z': ['SLESZ'],
#  's7l': ['special'],
#  'a9e': ['available'],
#  'f9s': ['functions'],
#  'p7e': ['package'],
#  'a3i': ['api'],
#  'g6g': ['golang'],
#  'e11s': ['experiments'],
#  'p10e': ['precedence'],
#  'S11S': ['STARTNAWIAS'],
#  'H7G': ['HASZTAG'],
#  'J5N': ['JEDEN'],
#  'Z4O': ['ZERO'],
#  'T4Y': ['TRZY'],
#  'O5M': ['OSIEM'],
#  'S10S': ['STOPNAWIAS'],
#  'e10t': ['experiment'],
#  'c6e': ['change'],
#  'i2n': ['in'],
#  'g6e': ['gentle'],
#  'f5e': ['force'],
#  'D3A': ['DWA'],
#  'm6y': ['modify'],
#  'b8r': ['behavior'],
#  'f4g': ['flag'],
#  'r6e': ['remote'],
#  't9s': ['taskfiles'],
#  'S6M': ['SIEDEM'],
#  'e15n': ['experimentation'],
#  'u5g': ['using'],
#  's6d': ['stored'],
#  'l9s': ['locations'],
#  'd12s': ['deprecations'],
#  'c10n': ['completion'],
#  's7s': ['scripts', 'schemas'],
#  'd11n': ['deprecation'],
#  'd6t': ['direct'],
#  't6s': ['task’s'],
#  'g3t': ['git'],
#  'd9y': ['directory'],
#  's4e': ['some'],
#  'g8e': ['guidance'],
#  'o2n': ['on'],
#  't5r': ['their'],
#  'r12s': ['replacements'],
#  'v7n': ['version'],
#  'D9I': ['DZIEWIECI'],
#  'm9n': ['migration'],
#  'o5r': ['other'],
#  'd11g': ['documenting'],
#  'd10d': ['deprecated'],
#  'f8s': ['features'],
#  'c9y': ['community'],
#  'c13s': ['contributions'],
#  'i12n': ['installation'],
#  'm7s': ['methods'],
#  'i12s': ['integrations'],
#  'm10d': ['maintained'],
#  't5d': ['third'],
#  'p7s': ['parties'],
#  'f3q': ['faq'],
#  'f10y': ['frequently'],
#  'a5d': ['asked'],
#  'q9s': ['questions'],
#  'a5t': ['about'],
#  'i9g': ['including'],
#  'e4s': ['etas'],
#  's5l': ['shell'],
#  'l11s': ['limitations'],
#  'w7s': ['windows'],
#  'c13y': ['compatibility'],
#  'g7g': ['getting'],
#  's7d': ['started'],
#  'o8l': ['official'],
#  'v2s': ['vs'],
#  'c4e': ['code'],
#  'j4n': ['json'],
#  't5s': ['tools'],
#  'v8s': ['versions'],
#  'h3w': ['how'],
#  'u3e': ['use'],
#  'e6e': ['ensure'],
#  'u5s': ['users'],
#  'a3e': ['are'],
#  'c7t': ['correct']}

# %%
from lark import Lark
json_parser = Lark(r"""
    value: dict
         | list
         | ESCAPED_STRING
         | SIGNED_NUMBER
         | "true" | "false" | "null"

    list : "[" [value ("," value)*] "]"

    dict : "{" [pair ("," pair)*] "}"
    pair : ESCAPED_STRING ":" value

    # %import common.ESCAPED_STRING
    # %import common.SIGNED_NUMBER
    # %import common.WS
    # %ignore WS

    """, start='value')

x = requests.get("https://api.github.com/gists/public").text
y = json_parser.parse(x)
print( y.pretty() )
# Out:
# value
#   list
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/565724332179ef8f0335b8181d544275"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/565724332179ef8f0335b8181d544275/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/565724332179ef8f0335b8181d544275/commits"
#         pair
#           "id"
#           value	"565724332179ef8f0335b8181d544275"
#         pair
#           "node_id"
#           value	"G_kwDOAWatx9oAIDU2NTcyNDMzMjE3OWVmOGYwMzM1YjgxODFkNTQ0Mjc1"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/565724332179ef8f0335b8181d544275.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/565724332179ef8f0335b8181d544275.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/HugsLibRecordKeeper/565724332179ef8f0335b8181d544275"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "output_log.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"output_log.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/HugsLibRecordKeeper/565724332179ef8f0335b8181d544275/raw/62c1bee3e7fe4d88600abb18b5e451f9dd92bc3b/output_log.txt"
#                     pair
#                       "size"
#                       value	395444
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:52:35Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:52:37Z"
#         pair
#           "description"
#           value	"Rimworld output log published using HugsLib"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/565724332179ef8f0335b8181d544275/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"HugsLibRecordKeeper"
#               pair
#                 "id"
#                 value	23506375
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjIzNTA2Mzc1"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/23506375?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper"
#               pair
#                 "html_url"
#                 value	"https://github.com/HugsLibRecordKeeper"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/8ebaa35eba4285b2736246382bf4fca7"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/8ebaa35eba4285b2736246382bf4fca7/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/8ebaa35eba4285b2736246382bf4fca7/commits"
#         pair
#           "id"
#           value	"8ebaa35eba4285b2736246382bf4fca7"
#         pair
#           "node_id"
#           value	"G_kwDOAF-wA9oAIDhlYmFhMzVlYmE0Mjg1YjI3MzYyNDYzODJiZjRmY2E3"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/8ebaa35eba4285b2736246382bf4fca7.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/8ebaa35eba4285b2736246382bf4fca7.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/choco-bot/8ebaa35eba4285b2736246382bf4fca7"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "FilesSnapshot.xml"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"FilesSnapshot.xml"
#                     pair
#                       "type"
#                       value	"application/xml"
#                     pair
#                       "language"
#                       value	"XML"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/8ebaa35eba4285b2736246382bf4fca7/raw/ba20abcfe9736b4ec55463b05f36b25c1f80d96a/FilesSnapshot.xml"
#                     pair
#                       "size"
#                       value	1356
#               pair
#                 "Install.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"Install.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/8ebaa35eba4285b2736246382bf4fca7/raw/fc7f56c07316c399b30e355317382b2ed68467bd/Install.txt"
#                     pair
#                       "size"
#                       value	183738
#               pair
#                 "Uninstall.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"Uninstall.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/8ebaa35eba4285b2736246382bf4fca7/raw/b7d9b96fa926d70240c2ce4c94f3fca414259ee6/Uninstall.txt"
#                     pair
#                       "size"
#                       value	54658
#               pair
#                 "_Summary.md"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"_Summary.md"
#                     pair
#                       "type"
#                       value	"text/markdown"
#                     pair
#                       "language"
#                       value	"Markdown"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/8ebaa35eba4285b2736246382bf4fca7/raw/f7cdbe74413b53c1fa907eb6595341ad5ef5f387/_Summary.md"
#                     pair
#                       "size"
#                       value	490
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:51:00Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:51:01Z"
#         pair
#           "description"
#           value	"pcsx2-dev v2.7.210-dev - Passed - Package Tests Results"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/8ebaa35eba4285b2736246382bf4fca7/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"choco-bot"
#               pair
#                 "id"
#                 value	6270979
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjYyNzA5Nzk="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/6270979?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/choco-bot"
#               pair
#                 "html_url"
#                 value	"https://github.com/choco-bot"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/choco-bot/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/choco-bot/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/choco-bot/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/choco-bot/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/choco-bot/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/choco-bot/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/choco-bot/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/choco-bot/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/choco-bot/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/0b9262adb247ecaae72055542be51027"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/0b9262adb247ecaae72055542be51027/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/0b9262adb247ecaae72055542be51027/commits"
#         pair
#           "id"
#           value	"0b9262adb247ecaae72055542be51027"
#         pair
#           "node_id"
#           value	"G_kwDOABmBMdoAIDBiOTI2MmFkYjI0N2VjYWFlNzIwNTU1NDJiZTUxMDI3"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/0b9262adb247ecaae72055542be51027.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/0b9262adb247ecaae72055542be51027.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/rmrfus/0b9262adb247ecaae72055542be51027"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "2026-sierras-alt-denver.md"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"2026-sierras-alt-denver.md"
#                     pair
#                       "type"
#                       value	"text/markdown"
#                     pair
#                       "language"
#                       value	"Markdown"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/rmrfus/0b9262adb247ecaae72055542be51027/raw/95a537caa6869463a225ba596ea55493cdfaa5ca/2026-sierras-alt-denver.md"
#                     pair
#                       "size"
#                       value	10133
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:50:48Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:50:48Z"
#         pair
#           "description"
#           value	"2026 Sierras — Denver hub plan"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/0b9262adb247ecaae72055542be51027/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"rmrfus"
#               pair
#                 "id"
#                 value	1671473
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjE2NzE0NzM="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/1671473?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/rmrfus"
#               pair
#                 "html_url"
#                 value	"https://github.com/rmrfus"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/rmrfus/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/rmrfus/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/rmrfus/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/rmrfus/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/rmrfus/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/rmrfus/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/rmrfus/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/rmrfus/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/rmrfus/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/9dd916793581d2f8705e037d795861ae"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/9dd916793581d2f8705e037d795861ae/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/9dd916793581d2f8705e037d795861ae/commits"
#         pair
#           "id"
#           value	"9dd916793581d2f8705e037d795861ae"
#         pair
#           "node_id"
#           value	"G_kwDOABXZYNoAIDlkZDkxNjc5MzU4MWQyZjg3MDVlMDM3ZDc5NTg2MWFl"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/9dd916793581d2f8705e037d795861ae.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/9dd916793581d2f8705e037d795861ae.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/konard/9dd916793581d2f8705e037d795861ae"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "solution-draft-log-pr-1774205438921.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"solution-draft-log-pr-1774205438921.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/konard/9dd916793581d2f8705e037d795861ae/raw/0f852c700f56b75407a11b215bb383efcf7278f7/solution-draft-log-pr-1774205438921.txt"
#                     pair
#                       "size"
#                       value	1834862
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:50:41Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:50:42Z"
#         pair
#           "description"
#           value	"Solution draft log for https://github.com/Jhon-Crow/godot-topdown-MVP/pull/1349"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/9dd916793581d2f8705e037d795861ae/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"konard"
#               pair
#                 "id"
#                 value	1431904
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjE0MzE5MDQ="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/1431904?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/konard"
#               pair
#                 "html_url"
#                 value	"https://github.com/konard"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/konard/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/konard/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/konard/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/konard/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/konard/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/konard/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/konard/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/konard/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/konard/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/622bf5e5b07371adbd4f5ee8fc5f0966"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/622bf5e5b07371adbd4f5ee8fc5f0966/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/622bf5e5b07371adbd4f5ee8fc5f0966/commits"
#         pair
#           "id"
#           value	"622bf5e5b07371adbd4f5ee8fc5f0966"
#         pair
#           "node_id"
#           value	"G_kwDOCHN4-doAIDYyMmJmNWU1YjA3MzcxYWRiZDRmNWVlOGZjNWYwOTY2"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/622bf5e5b07371adbd4f5ee8fc5f0966.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/622bf5e5b07371adbd4f5ee8fc5f0966.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/baranisyum/622bf5e5b07371adbd4f5ee8fc5f0966"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "readme.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"readme.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/baranisyum/622bf5e5b07371adbd4f5ee8fc5f0966/raw/d42dec442088e2f67826cc7bcfd2e02883e31dfe/readme.txt"
#                     pair
#                       "size"
#                       value	79
#               pair
#                 "script.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"script.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/baranisyum/622bf5e5b07371adbd4f5ee8fc5f0966/raw/fbed2d5c3827abd8898c9105b4edeeaa3f96842f/script.txt"
#                     pair
#                       "size"
#                       value	13268
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:50:36Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:50:36Z"
#         pair
#           "description"
#           value	"PCT731 (PuzzleScript Script)"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/622bf5e5b07371adbd4f5ee8fc5f0966/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"baranisyum"
#               pair
#                 "id"
#                 value	141785337
#               pair
#                 "node_id"
#                 value	"U_kgDOCHN4-Q"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/141785337?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/baranisyum"
#               pair
#                 "html_url"
#                 value	"https://github.com/baranisyum"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/baranisyum/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/baranisyum/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/baranisyum/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/baranisyum/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/baranisyum/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/baranisyum/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/baranisyum/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/baranisyum/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/baranisyum/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/090c7069415756111ebe63b85b38f589"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/090c7069415756111ebe63b85b38f589/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/090c7069415756111ebe63b85b38f589/commits"
#         pair
#           "id"
#           value	"090c7069415756111ebe63b85b38f589"
#         pair
#           "node_id"
#           value	"G_kwDOCeARvNoAIDA5MGM3MDY5NDE1NzU2MTExZWJlNjNiODViMzhmNTg5"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/090c7069415756111ebe63b85b38f589.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/090c7069415756111ebe63b85b38f589.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/ILTZWI/090c7069415756111ebe63b85b38f589"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "gistfile1.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"gistfile1.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/ILTZWI/090c7069415756111ebe63b85b38f589/raw/b02615c71c1ffeb93c81d4423ec7b5acb7080da5/gistfile1.txt"
#                     pair
#                       "size"
#                       value	7145
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:50:35Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:50:36Z"
#         pair
#           "description"
#           value	"ДЗ: Бой с боссом"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/090c7069415756111ebe63b85b38f589/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"ILTZWI"
#               pair
#                 "id"
#                 value	165679548
#               pair
#                 "node_id"
#                 value	"U_kgDOCeARvA"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/165679548?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/ILTZWI"
#               pair
#                 "html_url"
#                 value	"https://github.com/ILTZWI"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/ILTZWI/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/ILTZWI/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/ILTZWI/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/ILTZWI/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/ILTZWI/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/ILTZWI/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/ILTZWI/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/ILTZWI/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/ILTZWI/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/fb314b11f369fbe9b8df9c19a850358b"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/fb314b11f369fbe9b8df9c19a850358b/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/fb314b11f369fbe9b8df9c19a850358b/commits"
#         pair
#           "id"
#           value	"fb314b11f369fbe9b8df9c19a850358b"
#         pair
#           "node_id"
#           value	"G_kwDOAGhzctoAIGZiMzE0YjExZjM2OWZiZTliOGRmOWMxOWE4NTAzNThi"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/fb314b11f369fbe9b8df9c19a850358b.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/fb314b11f369fbe9b8df9c19a850358b.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/indatawetrust/fb314b11f369fbe9b8df9c19a850358b"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "privacy-policy.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"privacy-policy.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/indatawetrust/fb314b11f369fbe9b8df9c19a850358b/raw/53bd797b670e0c3b6b0005402c4f6c2674dbc9d0/privacy-policy.txt"
#                     pair
#                       "size"
#                       value	1167
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:50:09Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:50:35Z"
#         pair
#           "description"
#           value	"Privacy Policy"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/fb314b11f369fbe9b8df9c19a850358b/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"indatawetrust"
#               pair
#                 "id"
#                 value	6845298
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjY4NDUyOTg="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/6845298?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/indatawetrust"
#               pair
#                 "html_url"
#                 value	"https://github.com/indatawetrust"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/indatawetrust/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/indatawetrust/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/indatawetrust/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/indatawetrust/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/indatawetrust/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/indatawetrust/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/indatawetrust/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/indatawetrust/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/indatawetrust/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/42158357d203f2c8034df0b8d5dff109"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/42158357d203f2c8034df0b8d5dff109/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/42158357d203f2c8034df0b8d5dff109/commits"
#         pair
#           "id"
#           value	"42158357d203f2c8034df0b8d5dff109"
#         pair
#           "node_id"
#           value	"G_kwDOAF-wA9oAIDQyMTU4MzU3ZDIwM2YyYzgwMzRkZjBiOGQ1ZGZmMTA5"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/42158357d203f2c8034df0b8d5dff109.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/42158357d203f2c8034df0b8d5dff109.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/choco-bot/42158357d203f2c8034df0b8d5dff109"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "Install.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"Install.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/42158357d203f2c8034df0b8d5dff109/raw/1907515446178872f59d36a51b097146d603299c/Install.txt"
#                     pair
#                       "size"
#                       value	59519
#               pair
#                 "_Summary.md"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"_Summary.md"
#                     pair
#                       "type"
#                       value	"text/markdown"
#                     pair
#                       "language"
#                       value	"Markdown"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/choco-bot/42158357d203f2c8034df0b8d5dff109/raw/41841613c1b3a255d288a06d4b6f5d3a8a0423fe/_Summary.md"
#                     pair
#                       "size"
#                       value	658
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:49:24Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:49:25Z"
#         pair
#           "description"
#           value	"Amiri v0.111 - Failed - Package Tests Results"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/42158357d203f2c8034df0b8d5dff109/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"choco-bot"
#               pair
#                 "id"
#                 value	6270979
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjYyNzA5Nzk="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/6270979?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/choco-bot"
#               pair
#                 "html_url"
#                 value	"https://github.com/choco-bot"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/choco-bot/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/choco-bot/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/choco-bot/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/choco-bot/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/choco-bot/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/choco-bot/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/choco-bot/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/choco-bot/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/choco-bot/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/324400ddd3afd5d428461066c17be77d"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/324400ddd3afd5d428461066c17be77d/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/324400ddd3afd5d428461066c17be77d/commits"
#         pair
#           "id"
#           value	"324400ddd3afd5d428461066c17be77d"
#         pair
#           "node_id"
#           value	"G_kwDOA6xBhNoAIDMyNDQwMGRkZDNhZmQ1ZDQyODQ2MTA2NmMxN2JlNzdk"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/324400ddd3afd5d428461066c17be77d.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/324400ddd3afd5d428461066c17be77d.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/evgTSV/324400ddd3afd5d428461066c17be77d"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "relays_temp_control.c"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"relays_temp_control.c"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"C"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/evgTSV/324400ddd3afd5d428461066c17be77d/raw/cbe39c8bdb9dcf848875b58678577dcb2d445137/relays_temp_control.c"
#                     pair
#                       "size"
#                       value	14622
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:48:59Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:48:59Z"
#         pair
#           "description"
#           value	"Relays managing + Temp. Stuff: ESP32; TFT 128x160; DS18B20; Relays module (8 pcs); MQTT"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/324400ddd3afd5d428461066c17be77d/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"evgTSV"
#               pair
#                 "id"
#                 value	61620612
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjYxNjIwNjEy"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/61620612?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/evgTSV"
#               pair
#                 "html_url"
#                 value	"https://github.com/evgTSV"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/evgTSV/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/evgTSV/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/evgTSV/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/evgTSV/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/evgTSV/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/evgTSV/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/evgTSV/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/evgTSV/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/evgTSV/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/252d867f8cd1fe4a30f5cd07a93a51ae"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/252d867f8cd1fe4a30f5cd07a93a51ae/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/252d867f8cd1fe4a30f5cd07a93a51ae/commits"
#         pair
#           "id"
#           value	"252d867f8cd1fe4a30f5cd07a93a51ae"
#         pair
#           "node_id"
#           value	"G_kwDODTPAtdoAIDI1MmQ4NjdmOGNkMWZlNGEzMGY1Y2QwN2E5M2E1MWFl"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/252d867f8cd1fe4a30f5cd07a93a51ae.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/252d867f8cd1fe4a30f5cd07a93a51ae.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/sohamy2911/252d867f8cd1fe4a30f5cd07a93a51ae"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "MERN-Marketplace.md"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"MERN-Marketplace.md"
#                     pair
#                       "type"
#                       value	"text/markdown"
#                     pair
#                       "language"
#                       value	"Markdown"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/sohamy2911/252d867f8cd1fe4a30f5cd07a93a51ae/raw/9cd130a4519672b1fcbde690ba0fe8f432364717/MERN-Marketplace.md"
#                     pair
#                       "size"
#                       value	4605
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:48:30Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:48:30Z"
#         pair
#           "description"
#           value	""
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/252d867f8cd1fe4a30f5cd07a93a51ae/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"sohamy2911"
#               pair
#                 "id"
#                 value	221495477
#               pair
#                 "node_id"
#                 value	"U_kgDODTPAtQ"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/221495477?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/sohamy2911"
#               pair
#                 "html_url"
#                 value	"https://github.com/sohamy2911"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/sohamy2911/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/sohamy2911/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/sohamy2911/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/sohamy2911/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/sohamy2911/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/sohamy2911/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/sohamy2911/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/sohamy2911/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/sohamy2911/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/8913a24b66347d2d96825d29f158ead5"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/8913a24b66347d2d96825d29f158ead5/forks"
#         pair
#           "commits_url"
# ...
#         pair
#           "updated_at"
#           value	"2026-03-22T18:44:45Z"
#         pair
#           "description"
#           value	""
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/0ca7af26a27a55b54c47d5f1ba877659/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"ZkAleeJoo"
#               pair
#                 "id"
#                 value	202456150
#               pair
#                 "node_id"
#                 value	"U_kgDODBE8Vg"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/202456150?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/ZkAleeJoo"
#               pair
#                 "html_url"
#                 value	"https://github.com/ZkAleeJoo"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/ZkAleeJoo/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/f2c8e7e068715bb96b4555a4fd9cf1f3"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/f2c8e7e068715bb96b4555a4fd9cf1f3/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/f2c8e7e068715bb96b4555a4fd9cf1f3/commits"
#         pair
#           "id"
#           value	"f2c8e7e068715bb96b4555a4fd9cf1f3"
#         pair
#           "node_id"
#           value	"G_kwDOABXZYNoAIGYyYzhlN2UwNjg3MTViYjk2YjQ1NTVhNGZkOWNmMWYz"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/f2c8e7e068715bb96b4555a4fd9cf1f3.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/f2c8e7e068715bb96b4555a4fd9cf1f3.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/konard/f2c8e7e068715bb96b4555a4fd9cf1f3"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "solution-draft-log-pr-1774205035234.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"solution-draft-log-pr-1774205035234.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/konard/f2c8e7e068715bb96b4555a4fd9cf1f3/raw/7bbb35797d78fcd1887f28da19e2b1a50098750c/solution-draft-log-pr-1774205035234.txt"
#                     pair
#                       "size"
#                       value	4603979
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:43:57Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:44:00Z"
#         pair
#           "description"
#           value	"Solution draft log for https://github.com/Jhon-Crow/godot-topdown-MVP/pull/1243"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/f2c8e7e068715bb96b4555a4fd9cf1f3/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"konard"
#               pair
#                 "id"
#                 value	1431904
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjE0MzE5MDQ="
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/1431904?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/konard"
#               pair
#                 "html_url"
#                 value	"https://github.com/konard"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/konard/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/konard/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/konard/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/konard/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/konard/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/konard/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/konard/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/konard/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/konard/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/f709f84fbfd349203d5b58c04f69d116"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/f709f84fbfd349203d5b58c04f69d116/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/f709f84fbfd349203d5b58c04f69d116/commits"
#         pair
#           "id"
#           value	"f709f84fbfd349203d5b58c04f69d116"
#         pair
#           "node_id"
#           value	"G_kwDOAWatx9oAIGY3MDlmODRmYmZkMzQ5MjAzZDViNThjMDRmNjlkMTE2"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/f709f84fbfd349203d5b58c04f69d116.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/f709f84fbfd349203d5b58c04f69d116.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/HugsLibRecordKeeper/f709f84fbfd349203d5b58c04f69d116"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "output_log.txt"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"output_log.txt"
#                     pair
#                       "type"
#                       value	"text/plain"
#                     pair
#                       "language"
#                       value	"Text"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/HugsLibRecordKeeper/f709f84fbfd349203d5b58c04f69d116/raw/1a2481698003eeaf2e61c3f2061ad680648bb6f9/output_log.txt"
#                     pair
#                       "size"
#                       value	566687
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:43:34Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:43:35Z"
#         pair
#           "description"
#           value	"Rimworld output log published using HugsLib"
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/f709f84fbfd349203d5b58c04f69d116/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"HugsLibRecordKeeper"
#               pair
#                 "id"
#                 value	23506375
#               pair
#                 "node_id"
#                 value	"MDQ6VXNlcjIzNTA2Mzc1"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/23506375?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper"
#               pair
#                 "html_url"
#                 value	"https://github.com/HugsLibRecordKeeper"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/HugsLibRecordKeeper/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value
#     value
#       dict
#         pair
#           "url"
#           value	"https://api.github.com/gists/bc490eacd375b64539e7b1d3ba234d3c"
#         pair
#           "forks_url"
#           value	"https://api.github.com/gists/bc490eacd375b64539e7b1d3ba234d3c/forks"
#         pair
#           "commits_url"
#           value	"https://api.github.com/gists/bc490eacd375b64539e7b1d3ba234d3c/commits"
#         pair
#           "id"
#           value	"bc490eacd375b64539e7b1d3ba234d3c"
#         pair
#           "node_id"
#           value	"G_kwDOEBqD1toAIGJjNDkwZWFjZDM3NWI2NDUzOWU3YjFkM2JhMjM0ZDNj"
#         pair
#           "git_pull_url"
#           value	"https://gist.github.com/bc490eacd375b64539e7b1d3ba234d3c.git"
#         pair
#           "git_push_url"
#           value	"https://gist.github.com/bc490eacd375b64539e7b1d3ba234d3c.git"
#         pair
#           "html_url"
#           value	"https://gist.github.com/n35285692-prog/bc490eacd375b64539e7b1d3ba234d3c"
#         pair
#           "files"
#           value
#             dict
#               pair
#                 "Servers.json"
#                 value
#                   dict
#                     pair
#                       "filename"
#                       value	"Servers.json"
#                     pair
#                       "type"
#                       value	"application/json"
#                     pair
#                       "language"
#                       value	"JSON"
#                     pair
#                       "raw_url"
#                       value	"https://gist.githubusercontent.com/n35285692-prog/bc490eacd375b64539e7b1d3ba234d3c/raw/6843b47244c3b3cc1fbe1eefc4c667d137c2dfc8/Servers.json"
#                     pair
#                       "size"
#                       value	206
#         pair
#           "public"
#           value
#         pair
#           "created_at"
#           value	"2026-03-22T18:43:28Z"
#         pair
#           "updated_at"
#           value	"2026-03-22T18:43:28Z"
#         pair
#           "description"
#           value	""
#         pair
#           "comments"
#           value	0
#         pair
#           "user"
#           value
#         pair
#           "comments_enabled"
#           value
#         pair
#           "comments_url"
#           value	"https://api.github.com/gists/bc490eacd375b64539e7b1d3ba234d3c/comments"
#         pair
#           "owner"
#           value
#             dict
#               pair
#                 "login"
#                 value	"n35285692-prog"
#               pair
#                 "id"
#                 value	270173142
#               pair
#                 "node_id"
#                 value	"U_kgDOEBqD1g"
#               pair
#                 "avatar_url"
#                 value	"https://avatars.githubusercontent.com/u/270173142?v=4"
#               pair
#                 "gravatar_id"
#                 value	""
#               pair
#                 "url"
#                 value	"https://api.github.com/users/n35285692-prog"
#               pair
#                 "html_url"
#                 value	"https://github.com/n35285692-prog"
#               pair
#                 "followers_url"
#                 value	"https://api.github.com/users/n35285692-prog/followers"
#               pair
#                 "following_url"
#                 value	"https://api.github.com/users/n35285692-prog/following{/other_user}"
#               pair
#                 "gists_url"
#                 value	"https://api.github.com/users/n35285692-prog/gists{/gist_id}"
#               pair
#                 "starred_url"
#                 value	"https://api.github.com/users/n35285692-prog/starred{/owner}{/repo}"
#               pair
#                 "subscriptions_url"
#                 value	"https://api.github.com/users/n35285692-prog/subscriptions"
#               pair
#                 "organizations_url"
#                 value	"https://api.github.com/users/n35285692-prog/orgs"
#               pair
#                 "repos_url"
#                 value	"https://api.github.com/users/n35285692-prog/repos"
#               pair
#                 "events_url"
#                 value	"https://api.github.com/users/n35285692-prog/events{/privacy}"
#               pair
#                 "received_events_url"
#                 value	"https://api.github.com/users/n35285692-prog/received_events"
#               pair
#                 "type"
#                 value	"User"
#               pair
#                 "user_view_type"
#                 value	"public"
#               pair
#                 "site_admin"
#                 value
#         pair
#           "truncated"
#           value

# %%
md = marko.Markdown()
md.use('footnote')
md.use('toc')
md.use('codehilite')
data = md(requests.get("https://github.com/Sarverott/Sarverott/raw/refs/heads/master/README.md").text)
md.renderer.render_toc()
# Out:
# '<ul>\n<li><a href="#hello-world">HELLO WORLD!</a></li>\n<li><a href="#some-statistical-data">Some statistical data</a></li>\n<li><a href="#links-to-my-actions">Links to my actions</a></li>\n<li><a href="#more-about">More about</a></li>\n</ul>\n'

# %%
#IPython.core.display.HTML()
# Out:
# <ul>
# <li><a href="#hello-world">HELLO WORLD!</a></li>
# <li><a href="#some-statistical-data">Some statistical data</a></li>
# <li><a href="#links-to-my-actions">Links to my actions</a></li>
# <li><a href="#more-about">More about</a></li>
# </ul>
